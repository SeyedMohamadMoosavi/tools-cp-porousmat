# %% [markdown]
# This notebook shows how to load trained ML models (see example_ML_training) and predict the heat capacity for new materials

# %%
from cp_app.featurizer import featurize_dataset
from cp_app.predictions import predict_Cv_ensemble_dataset_multitemperatures
from cp_app.descriptors import cv_features
import pandas as pd
import glob

# %% [markdown]
# ## Featurizing new materials

# %%
cif_list = glob.glob("cifs/*")

# %%
df_features = featurize_dataset(cif_list, verbos=False, saveto="data/features_example1.csv")
# Out:
# /Users/moosavi/miniconda3/envs/cpenv/lib/python3.9/site-packages/pymatgen/io/cif.py:1160: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: %s" % "\n".join(self.warnings))
# site elemental properties
# AGNI
# GSF
# LPD

# %%
df_features.head()
# Out:
#               structure_name structure_path site Number site AtomicWeight  \
# 18150N2.cif_0    18150N2.cif           cifs         1.0           1.00794
# 18150N2.cif_1    18150N2.cif           cifs         1.0           1.00794
# 18150N2.cif_2    18150N2.cif           cifs         1.0           1.00794
# 18150N2.cif_3    18150N2.cif           cifs         1.0           1.00794
# 18150N2.cif_4    18150N2.cif           cifs         1.0           1.00794
#
#               site Row site Column site Electronegativity site CovalentRadius  \
# 18150N2.cif_0      1.0         1.0                    2.2                31.0
# 18150N2.cif_1      1.0         1.0                    2.2                31.0
# 18150N2.cif_2      1.0         1.0                    2.2                31.0
# 18150N2.cif_3      1.0         1.0                    2.2                31.0
# 18150N2.cif_4      1.0         1.0                    2.2                31.0
#
#               AGNI eta=8.00e-01 AGNI eta=1.23e+00  ...  \
# 18150N2.cif_0          0.139803          0.467199  ...
# 18150N2.cif_1          0.130159           0.52907  ...
# 18150N2.cif_2          0.141849           0.51371  ...
# 18150N2.cif_3          0.136132          0.509148  ...
# 18150N2.cif_4          0.139793          0.498658  ...
#
#               maximum local difference in Row  \
# 18150N2.cif_0                             2.0
# 18150N2.cif_1                             1.0
# 18150N2.cif_2                             2.0
# 18150N2.cif_3                             1.0
# 18150N2.cif_4                             2.0
#
#               maximum local difference in Column  \
# 18150N2.cif_0                               16.0
# 18150N2.cif_1                               15.0
# 18150N2.cif_2                               16.0
# 18150N2.cif_3                               15.0
# 18150N2.cif_4                               16.0
#
#               maximum local difference in Electronegativity  \
# 18150N2.cif_0                                          1.24
# 18150N2.cif_1                                          1.24
# 18150N2.cif_2                                          1.24
# 18150N2.cif_3                                          1.24
# 18150N2.cif_4                                          1.24
#
#               maximum local difference in CovalentRadius  \
# 18150N2.cif_0                                       71.0
# 18150N2.cif_1                                       45.0
# 18150N2.cif_2                                       71.0
# 18150N2.cif_3                                       45.0
# 18150N2.cif_4                                       71.0
#
#               minimum local difference in Number  \
# 18150N2.cif_0                                0.0
# 18150N2.cif_1                                0.0
# 18150N2.cif_2                                0.0
# 18150N2.cif_3                                0.0
# 18150N2.cif_4                                0.0
#
#               minimum local difference in AtomicWeight  \
# 18150N2.cif_0                                      0.0
# 18150N2.cif_1                                      0.0
# 18150N2.cif_2                                      0.0
# 18150N2.cif_3                                      0.0
# 18150N2.cif_4                                      0.0
#
#               minimum local difference in Row  \
# 18150N2.cif_0                             0.0
# 18150N2.cif_1                             0.0
# 18150N2.cif_2                             0.0
# 18150N2.cif_3                             0.0
# 18150N2.cif_4                             0.0
#
#               minimum local difference in Column  \
# 18150N2.cif_0                                0.0
# 18150N2.cif_1                                0.0
# 18150N2.cif_2                                0.0
# 18150N2.cif_3                                0.0
# 18150N2.cif_4                                0.0
#
#               minimum local difference in Electronegativity  \
# 18150N2.cif_0                                           0.0
# 18150N2.cif_1                                           0.0
# 18150N2.cif_2                                           0.0
# 18150N2.cif_3                                           0.0
# 18150N2.cif_4                                           0.0
#
#               minimum local difference in CovalentRadius
# 18150N2.cif_0                                        0.0
# 18150N2.cif_1                                        0.0
# 18150N2.cif_2                                        0.0
# 18150N2.cif_3                                        0.0
# 18150N2.cif_4                                        0.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Predicting heat capacity

# %% [markdown]
# Note: first run example_ML_training to make the ensemble ML models

# %%
df_predictions=predict_Cv_ensemble_dataset_multitemperatures(path_to_models="ensemble_models_smallML_120_10", features_file="data/features_example1.csv", FEATURES=cv_features, temperatures=[300.00],save_to="data/cv_predictions_example1.csv")
# Out:
# predicting Cp for 8 structures
# loading models for: 300.0
# /Users/moosavi/miniconda3/envs/cpenv/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 10 models loaded, predicting...

# %%
df_predictions
# Out:
#           name  Cv_gravimetric_300.0_mean  Cv_gravimetric_300.0_std  \
# 0  18150N2.cif                   0.860613                  0.005352
# 1  RSM0332.cif                   0.806066                  0.005838
# 2      AFR.cif                   0.733624                  0.000504
# 3  RSM0321.cif                   0.888088                  0.015695
# 4  RSM0306.cif                   0.816686                  0.001603
# 5  RSM0304.cif                   0.919904                  0.003983
# 6      AFI.cif                   0.737016                  0.000595
# 7  16050N2.cif                   0.884789                  0.001233
#
#    Cv_molar_300.0_mean  Cv_molar_300.0_std
# 0            11.071818            0.068860
# 1             9.876931            0.071537
# 2            14.693092            0.010085
# 3             9.224503            0.163019
# 4            11.406094            0.022393
# 5             9.774803            0.042326
# 6            14.761021            0.011919
# 7             9.450615            0.013171
